# %%
run runAllAlanineMAOnly.py
# Out:
# Processing C1-1
# Processing C1-2
# Processing C1-3
# Processing C1-4
# Processing C2-1
# Processing C2-2
# Processing C2-3
# Processing C2-4
# Processing C3-1
# Processing C3-2
# Processing C3-3
# Processing C3-4
